# %%
import pandas as pd #Importing pandas library

# %%
df=pd.read_csv("/content/Salaries.csv")

#Most of the data for analysis is available in the form of a tabular format such as  Excel and Comma Separated files(CSV).
#To access data from csv file, we require a function read_csv() that retrieves data in the form of data frame.

# %%
df #data
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head() #Pandas head() method is used to return top n (5 by default) rows of a data frame or series.
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10) #List first ten records
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(15) #List first fifteen records
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750

# %%
df.head(20) #List first twenty records
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.dtypes #Pandas DataFrame.dtypes attribute return the dtypes in the DataFrame. It returns a Series with the data type of each column.
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df['salary'].dtype #Pandas DataFrame.dtypes attribute return the dtypes in the DataFrame. It returns a Series with the data type of each column.
# Out:
# dtype('int64')

# %%
df.columns 

#Pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#Arithmetic operations align on both row and column labels.
#It can be thought of as a dict-like container for Series objects. This is the primary data structure of the Pandas.
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes 

#list the row labels and column names. 
#Pandas DataFrame.axes attribute access a group of rows and columns by label(s) or a boolean array in the given DataFrame.
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.ndim #Pandas Series.ndim attribute returns the number of dimensions of the underlying data, by definition it is 1 for series objects.
# Out:
# 2

# %%
df.size #Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
# Out:
# 468

# %%
df.shape #Returns tuple of shape (Rows, columns) of dataframe/series
# Out:
# (78, 6)

# %%
df.values

#The values property is used to get a Numpy representation of the DataFrame.
#Only the values in the DataFrame will be returned, the axes labels will be removed.
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.shape[0] #return a size of rows
# Out:
# 78

# %%
df.shape[1] #return size of column
# Out:
# 6

# %%
df.describe() #Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.min()

#Pandas dataframe.min() function returns the minimum of the values in the given object.
#If the input is a series, the method will return a scalar which will be the minimum of the values in the series.
#If the input is a dataframe, then the method will return a series with minimum of values over the specified axis in the dataframe.
#By default the axis is the index axis.
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()

#Pandas dataframe.max() function returns the maximum of the values in the given object.
#If the input is a series, the method will return a scalar which will be the maximum of the values in the series.
#If the input is a dataframe,then the method will return a series with maximum of values over the specified axis in the dataframe.
#By default the axis is the index axis.
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.mean() #return mean values of all numeric columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median() #return median values of all numeric columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std() #return standard deviation values of all numeric columns
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.sample(10) #Pandas sample() is used to generate a sample random row or column from the function caller data frame.
# Out:
#          rank discipline  phd  service     sex  salary
# 59  AssocProf          B   12       10  Female  103994
# 58       Prof          B   36       26  Female  144651
# 3        Prof          A   40       31    Male  131205
# 31       Prof          B   22       21    Male  155750
# 55   AsstProf          A    2        0  Female   72500
# 22   AsstProf          A    4        2    Male   73000
# 63       Prof          A   29       27  Female   91000
# 35       Prof          B   28       23    Male  126933
# 61  AssocProf          B   13       10  Female  103750
# 40       Prof          A   39       36  Female  137000

# %%
#what is the mean of first 50 records in database ?
df.head(50).mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.rank
# Out:
# <bound method NDFrame.rank of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df[["salary"]]
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
#calculate the basic statistics for phd column
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
#find out how many values in phd column.
df.phd.count()
# Out:
# 78

# %%
#calculate the average phd.
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df_rank=df.groupby(["rank"])

#Pandas groupby is used for grouping the data according to the categories and apply a function to the categories.
#It also helps to aggregate data efficiently.
#Pandas dataframe.groupby() function is used to split the data into groups based on some criteria.
#pandas objects can be split on any of their axes.
#The abstract definition of grouping is to provide a mapping of labels to group names.

# %%
df_rank.mean() #calculate mean value for each numeric column per each group
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df_rank

# %%
df.groupby("rank").mean() #Calculating mean by chain method
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby("rank")[["salary"]].mean() #calculate mean salary for each professor rank
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df[["salary"]]>120000
# Out:
#     salary
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# ..     ...
# 73   False
# 74   False
# 75    True
# 76   False
# 77   False
#
# [78 rows x 1 columns]

# %%
df.salary>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df.salary>120000] #data frame filtering
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#select only those rows that contains female professors only
df[["sex"]]=="Female"
# Out:
#       sex
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 73   True
# 74   True
# 75   True
# 76   True
# 77   True
#
# [78 rows x 1 columns]

# %%
df[df.sex=="Female"]
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
#The Pandas library provides a unique method to retrieve rows from a Data Frame. 
#Dataframe.iloc[] method is used when the index label of a data frame is something other than 
#numeric series of 0, 1, 2, 3….n or in case the user doesn’t know the index label.
#Rows can be extracted using an imaginary index position which isn’t visible in the data frame.

# %%
df.iloc[1] #First row of dataframe
# Out:
# rank           Prof
# discipline        A
# phd              12
# service           6
# sex            Male
# salary        93000
# Name: 1, dtype: object

# %%
df.iloc[-1] #Last row of comment
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           15
# sex           Female
# salary        109646
# Name: 77, dtype: object

# %%
df.iloc[:,1] #First Column of dataframe
# Out:
# 0     B
# 1     A
# 2     A
# 3     A
# 4     B
#      ..
# 73    B
# 74    B
# 75    B
# 76    A
# 77    A
# Name: discipline, Length: 78, dtype: object

# %%
df.iloc[:,-1] #Last Column of dataframe
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.iloc[0:7] #First seven rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[:0:2] #First two columns
# Out:
# Empty DataFrame
# Columns: [rank, discipline, phd, service, sex, salary]
# Index: []

# %%
df.iloc[1:3, 0:2] #First and Seconf Rows and first two columns
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[[0,5],[1,3]] #First and fifth rows and first two columns
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
#End Of Code
